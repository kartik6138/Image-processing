# %%
import cv2
from PIL import Image
img=cv2.imread('D:\pic3.jpg')
cv2.imshow('Image',img)
cv2.waitKey(0)
# Out:
# -1

# %%
height=img.shape[0]
width=img.shape[1]
channels=img.shape[2]
size1=img.size

print('Image Height :',height)
print('Image Width :',width)
print('Number of Channels :',channels)
print("Image Size :",size1)
# Out:
# Image Height : 1466
# Image Width : 2048
# Number of Channels : 3
# Image Size : 9007104

# %%
import cv2
from PIL import Image
filepath="bird.jpg"
img2=Image.open(filepath)
new_img=img2.resize((500,500))
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x231B252ACA0>

# %%
import cv2
img3=cv2.imread('D:/threads.jpg')
ret,bw_img3=cv2.threshold(img3,127,255,cv2.THRESH_BINARY)

cv2.imshow("BINARY",bw_img3)
cv2.waitKey(0)
# Out:
# -1

# %%
import cv2
img2=cv2.imread('D:/bubbles.jpg')
cv2.waitKey(0)
print("The shape of the image is :",img2.shape)
print("The Array of the Image is :")
print(img2)
# Out:
# The shape of the image is : (854, 960, 3)
# The Array of the Image is :
# [[[  7   5 241]
#   [  7   5 241]
#   [  7   5 241]
#   ...
#   [133 173 208]
#   [133 173 208]
#   [133 173 208]]
#
#  [[  7   5 241]
#   [  7   5 241]
#   [  7   5 241]
#   ...
#   [133 173 208]
#   [133 173 208]
#   [133 173 208]]
#
#  [[  7   5 241]
#   [  7   5 241]
#   [  7   5 241]
#   ...
#   [133 173 208]
#   [133 173 208]
#   [133 173 208]]
#
#  ...
#
#  [[  3   4 249]
#   [  3   4 249]
#   [  3   4 249]
#   ...
#   [  3  53 255]
#   [  3  53 255]
#   [  3  53 255]]
#
#  [[  3   4 249]
#   [  3   4 249]
#   [  3   4 249]
#   ...
#   [  3  53 255]
#   [  3  53 255]
#   [  3  53 255]]
#
#  [[  4   5 250]
#   [  4   5 250]
#   [  4   5 250]
#   ...
#   [  3  53 255]
#   [  3  53 255]
#   [  3  53 255]]]
